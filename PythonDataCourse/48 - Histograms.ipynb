# %%
import numpy as np
from numpy.random import randn
import pandas as pd

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 1.,  3.,  6., 17., 20., 22., 17.,  8.,  4.,  2.]),
#  array([-2.5487836 , -2.02835916, -1.50793472, -0.98751028, -0.46708584,
#          0.0533386 ,  0.57376303,  1.09418747,  1.61461191,  2.13503635,
#          2.65546079]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

plt.hist(dataset2,color='red')
# Out:
# (array([ 2.,  3., 11.,  6.,  9., 15., 15.,  9.,  5.,  5.]),
#  array([-2.24763357, -1.82080407, -1.39397458, -0.96714508, -0.54031558,
#         -0.11348609,  0.31334341,  0.74017291,  1.1670024 ,  1.5938319 ,
#          2.0206614 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,density=True,color='red',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.0585714 , 0.0585714 , 0.0585714 , 0.11714279, 0.35142838,
#         0.29285699, 0.17571419, 0.17571419, 0.23428559, 0.29285699,
#         0.52714257, 0.35142838, 0.35142838, 0.52714257, 0.23428559,
#         0.29285699, 0.        , 0.29285699, 0.11714279, 0.17571419]),
#  array([-2.24763357, -2.03421882, -1.82080407, -1.60738932, -1.39397458,
#         -1.18055983, -0.96714508, -0.75373033, -0.54031558, -0.32690083,
#         -0.11348609,  0.09992866,  0.31334341,  0.52675816,  0.74017291,
#          0.95358766,  1.1670024 ,  1.38041715,  1.5938319 ,  1.80724665,
#          2.0206614 ]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

sns.jointplot(data1,data2)
# Out:
# C:\Users\Hege\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# C:\Users\Hege\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
