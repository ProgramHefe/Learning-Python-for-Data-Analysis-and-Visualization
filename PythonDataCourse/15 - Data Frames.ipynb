# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas import Series,DataFrame

# %%
import webbrowser
website='https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Rank
# Out:
# 1  Green      Bay         Packers
# 2  Dallas     Cowboys         932
# 3  Baltimore  Ravens          402
# 4  Chicago    Bears         1,420
# 5  New        England    Patriots
# Name: Rank, dtype: object

# %%
nfl_frame_updated = pd.read_clipboard()

# %%
nfl_frame_updated
# Out:
#                                  Rank   Team   GP  Won    Lost      Tied  \
# 1  Green        Bay           Packers  1,386  770  578  38.000     0.569
# 2  Dallas       Cowboys           932    527  399    6   0.569  1960.000
# 3  Baltimore    Ravens            402    226  175    1   0.563  1996.000
# 4  Chicago      Bears           1,420    778  600   42   0.563  1920.000
# 5  New          England      Patriots    934  520  405   9.000     0.562
# 6  Miami        Dolphins          850    468  378    4   0.553  1966.000
# 7  Minnesota    Vikings           920    495  414   11   0.544  1961.000
# 8  San          Francisco       49ers  1,106  591  499  16.000     0.542
# 9  Kansas       City           Chiefs    934  496  426  12.000     0.537
# 10 Pittsburgh   Steelers        1,222    644  557   21   0.536  1933.000
# 11 New          York           Giants  1,355  702  620  33.000     0.530
# 12 Denver       Broncos           934    490  434   10   0.530  1960.000
# ...

# %%
nfl_frame['First Season']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'First Season'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-4cdf8532df16> in <module>
# ----> 1 nfl_frame['First Season']
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'Season',
#        'Division'],
#       dtype='object')

# %%
DataFrame(nfl_frame,columns=['Team','Won','GP','Stadium'])
# Out:
#                       Team  Won   GP  Stadium
# 1 Green     Bay      1,386  578  770      NaN
# 2 Dallas    Cowboys    527    6  399      NaN
# 3 Baltimore Ravens     226    1  175      NaN
# 4 Chicago   Bears      778   42  600      NaN
# 5 New       England    934  405  520      NaN

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
nfl_frame.head(3)
# Out:
#                         Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay      Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys      932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens       402    226  175    1   0.563  1996.000   AFC  North
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None

# %%
nfl_frame.tail(3)
# Out:
#                          Rank Team   GP  Won   Lost      Tied  Pct. Season  \
# 3 Baltimore Ravens        402  226  175    1  0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420  778  600   42  0.563  1920.000   NFC  North
# 5 New       England  Patriots  934  520  405  9.000     0.562  1960    AFC
#
#                     Division
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
nfl_frame.ix[3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ab12edb6de57> in <module>
# ----> 1 nfl_frame.ix[3]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
nfl_frame['Stadium'] = "Gilette Stadium"

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division          Stadium
# 1 Green     Bay        North  Gilette Stadium
# 2 Dallas    Cowboys     None  Gilette Stadium
# 3 Baltimore Ravens      None  Gilette Stadium
# 4 Chicago   Bears       None  Gilette Stadium
# 5 New       England     East  Gilette Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division  Stadium
# 1 Green     Bay        North        0
# 2 Dallas    Cowboys     None        1
# 3 Baltimore Ravens      None        2
# 4 Chicago   Bears       None        3
# 5 New       England     East        4

# %%
stadiums = Series(["Gilette Stadium","AT&T"],index=[4,0])

# %%
stadiums
# Out:
# 4    Gilette Stadium
# 0               AT&T
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division Stadium
# 1 Green     Bay        North     NaN
# 2 Dallas    Cowboys     None     NaN
# 3 Baltimore Ravens      None     NaN
# 4 Chicago   Bears       None     NaN
# 5 New       England     East     NaN

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#                          Rank   Team   GP  Won    Lost      Tied  Pct. Season  \
# 1 Green     Bay       Packers  1,386  770  578  38.000     0.569  1921    NFC
# 2 Dallas    Cowboys       932    527  399    6   0.569  1960.000   NFC   East
# 3 Baltimore Ravens        402    226  175    1   0.563  1996.000   AFC  North
# 4 Chicago   Bears       1,420    778  600   42   0.563  1920.000   NFC  North
# 5 New       England  Patriots    934  520  405   9.000     0.562  1960    AFC
#
#                     Division
# 1 Green     Bay        North
# 2 Dallas    Cowboys     None
# 3 Baltimore Ravens      None
# 4 Chicago   Bears       None
# 5 New       England     East

# %%
data = {'City':['SF','LA','NYC'],'Popul':[853535,3446644,23232]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City    Popul
# 0   SF   853535
# 1   LA  3446644
# 2  NYC    23232
